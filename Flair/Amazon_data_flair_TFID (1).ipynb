# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re
from textblob import TextBlob
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns',None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import random


from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from wordcloud import WordCloud
import cufflinks as cf
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots


pd.set_option('display.max_columns',None)

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from collections import Counter
from string import punctuation

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score , f1_score, accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Dense , Embedding , Bidirectional , LSTM

lemma = WordNetLemmatizer()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df = pd.read_csv("/content/Amazon_cellphone (1).csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                             Review  Rating  \
# 0           0  They look good and stick good! I just don't li...       1
# 1           1  These stickers work like the review says they ...       1
# 2           2  These are awesome and make my phone look so st...       1
# 3           4  awesome! stays on, and looks great. can be use...       1
# 4           5  These make using the home button easy. My daug...       0
#
#    review_len
# 0          37
# 1          32
# 2          34
# 3          23
# 4          23

# %%
# df= df.drop(['ID','Rating'], axis = 1)

# %%
fdf = df.copy()

# %%
fdf
# Out:
#        Unnamed: 0                                             Review  Rating  \
# 0               0  They look good and stick good! I just don't li...       1
# 1               1  These stickers work like the review says they ...       1
# 2               2  These are awesome and make my phone look so st...       1
# 3               4  awesome! stays on, and looks great. can be use...       1
# 4               5  These make using the home button easy. My daug...       0
# ...           ...                                                ...     ...
# 80356      194414  Get your stud their own studded case with this...       1
# 80357      194415  I got this case for the texture and I've been ...       1
# 80358      194434  Works great just like my original one. I reall...       1
# 80359      194435  Great product. Great packaging. High quality a...       1
# 80360      194437  I really like it becasue it works well with my...       1
#
#        review_len
# 0              37
# ...

# %%
df['Review'] = df['Review']

# %%
df = df.drop(['Unnamed: 0','Rating','review_len'],1)

# %%
df
# Out:
#                                                   Review
# 0      They look good and stick good! I just don't li...
# 1      These stickers work like the review says they ...
# 2      These are awesome and make my phone look so st...
# 3      awesome! stays on, and looks great. can be use...
# 4      These make using the home button easy. My daug...
# ...                                                  ...
# 80356  Get your stud their own studded case with this...
# 80357  I got this case for the texture and I've been ...
# 80358  Works great just like my original one. I reall...
# 80359  Great product. Great packaging. High quality a...
# 80360  I really like it becasue it works well with my...
#
# [80361 rows x 1 columns]

# %%
df = df.dropna()

# %%
df
# Out:
#                                                   Review
# 0      They look good and stick good! I just don't li...
# 1      These stickers work like the review says they ...
# 2      These are awesome and make my phone look so st...
# 3      awesome! stays on, and looks great. can be use...
# 4      These make using the home button easy. My daug...
# ...                                                  ...
# 80356  Get your stud their own studded case with this...
# 80357  I got this case for the texture and I've been ...
# 80358  Works great just like my original one. I reall...
# 80359  Great product. Great packaging. High quality a...
# 80360  I really like it becasue it works well with my...
#
# [80361 rows x 1 columns]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Download the 'stopwords' resource
nltk.download('stopwords')

# Download the 'wordnet' resource for lemmatization
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def DataPrep(text) :
    text = re.sub(r'\d+', '', text) # numbers
    text = re.sub(r'[^\w\s]', '', text) # special characters

    # tokenization
    tokens = nltk.word_tokenize(text)

    # remove puncs
    punc = list(punctuation)
    words = [word for word in tokens if word not in punc]

    # remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word.lower() for word in words if not word in stop_words]

    # lemmatization
    words = [lemma.lemmatize(word) for word in words]

    text = ' '.join(words)

    return text

# %%
df['cleaned_Reviews'] = df['Review'].apply(DataPrep)

# %%
pip install flair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.2/387.2 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 19.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 75.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 25.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 114.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 93.1 MB/s eta 0:00:00
# ...

# %%
pip install --upgrade urllib3
# Out:
# ...
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.32.3 requires urllib3<2.1,>=1.25.4; python_version >= "3.10", but you have urllib3 2.1.0 which is incompatible.
# flair 0.13.0 requires urllib3<2.0.0,>=1.0.0, but you have urllib3 2.1.0 which is incompatible.
# ...

# %%
from flair.models import TextClassifier
from flair.data import Sentence
classifier = TextClassifier.load('sentiment')

def extract_sentiment_label(row):
    sentence = Sentence(row)
    classifier.predict(sentence)

    if sentence.labels:
        label = sentence.labels[0].value
        if label == 'POSITIVE':
            return "Positive"
        elif label == 'NEGATIVE':
            return "Negative"

    return "Neutral"
# Out:
# 2023-11-19 17:40:59,853 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_4.pt not found in cache, downloading to /tmp/tmpiu409ixx
# 100%|██████████| 253M/253M [00:24<00:00, 10.7MB/s]
# 2023-11-19 17:41:25,291 copying /tmp/tmpiu409ixx to cache at /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# 2023-11-19 17:41:25,706 removing temp file /tmp/tmpiu409ixx
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
df['Rating'] = df['cleaned_Reviews'].apply(extract_sentiment_label)
# Out:
# 2023-11-19 17:42:13,750 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:42:40,786 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:44:12,304 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:45:40,917 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:46:23,802 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:48:55,798 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:49:14,003 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:49:30,952 Warning: An empty Sentence was created! Are there empty strings in your dataset?
# 2023-11-19 17:50:24,543 Warning: An empty Sentence was created! Are there empty strings in your dataset?

# %%
df
# Out:
#                                                   Review  \
# 0      They look good and stick good! I just don't li...
# 1      These stickers work like the review says they ...
# 2      These are awesome and make my phone look so st...
# 3      awesome! stays on, and looks great. can be use...
# 4      These make using the home button easy. My daug...
# ...                                                  ...
# 80356  Get your stud their own studded case with this...
# 80357  I got this case for the texture and I've been ...
# 80358  Works great just like my original one. I reall...
# 80359  Great product. Great packaging. High quality a...
# 80360  I really like it becasue it works well with my...
#
#                                          cleaned_Reviews    Rating
# 0      they look good stick good i dont like rounded ...  Negative
# 1      these sticker work like review say they stick ...  Positive
# 2      these awesome make phone look stylish i used o...  Positive
# ...

# %%
df = df.drop(['Review'],1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-8d99cd25e0b9> in <cell line: 1>()
# ----> 1 df = df.drop(['Review'],1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df
# Out:
#                                          cleaned_Reviews    Rating
# 0      they look good stick good i dont like rounded ...  Negative
# 1      these sticker work like review say they stick ...  Positive
# 2      these awesome make phone look stylish i used o...  Positive
# 3      awesome stay look great used multiple apple pr...  Positive
# 4      these make using home button easy my daughter ...  Positive
# ...                                                  ...       ...
# 80356  get stud studded case beautiful design it wort...  Positive
# 80357  i got case texture ive loving ever since i thi...  Positive
# 80358  work great like original one i really need ext...  Positive
# 80359  great product great packaging high quality app...  Positive
# 80360  i really like becasue work well life proof cas...  Positive
#
# [80361 rows x 2 columns]

# %%
dfff = df.copy()

# %%
dfff
# Out:
#                                          cleaned_Reviews    Rating
# 0      they look good stick good i dont like rounded ...  Negative
# 1      these sticker work like review say they stick ...  Positive
# 2      these awesome make phone look stylish i used o...  Positive
# 3      awesome stay look great used multiple apple pr...  Positive
# 4      these make using home button easy my daughter ...  Positive
# ...                                                  ...       ...
# 80356  get stud studded case beautiful design it wort...  Positive
# 80357  i got case texture ive loving ever since i thi...  Positive
# 80358  work great like original one i really need ext...  Positive
# 80359  great product great packaging high quality app...  Positive
# 80360  i really like becasue work well life proof cas...  Positive
#
# [80361 rows x 2 columns]

# %%
dfff['Rating'].unique()
# Out:
# array(['Negative', 'Positive', 'Neutral'], dtype=object)

# %%
def convert_labels(x):
    if x == 'Negative':
        return -1
    elif x == 'Positive':
        return 1
    elif x == 'Neutral':
        return 0  # You can handle other cases if needed

# %%
# Convert labels for each entry in the dataset
dfff['Rating'] = [convert_labels(x) for x in dfff['Rating']]

# %%
dfff
# Out:
#                                          cleaned_Reviews  Rating
# 0      they look good stick good i dont like rounded ...      -1
# 1      these sticker work like review say they stick ...       1
# 2      these awesome make phone look stylish i used o...       1
# 3      awesome stay look great used multiple apple pr...       1
# 4      these make using home button easy my daughter ...       1
# ...                                                  ...     ...
# 80356  get stud studded case beautiful design it wort...       1
# 80357  i got case texture ive loving ever since i thi...       1
# 80358  work great like original one i really need ext...       1
# 80359  great product great packaging high quality app...       1
# 80360  i really like becasue work well life proof cas...       1
#
# [80361 rows x 2 columns]

# %%
dfff.to_csv('Flair_amazon_data.csv')
