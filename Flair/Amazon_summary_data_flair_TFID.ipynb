# %%
import numpy as np
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re
from textblob import TextBlob
from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
# %matplotlib inline
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns',None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
import random


from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from wordcloud import WordCloud
import cufflinks as cf
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected = True)
cf.go_offline();
import plotly.graph_objs as go
from plotly.subplots import make_subplots


pd.set_option('display.max_columns',None)

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from collections import Counter
from string import punctuation

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score , f1_score, accuracy_score,confusion_matrix,ConfusionMatrixDisplay,classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.layers import Dense , Embedding , Bidirectional , LSTM

lemma = WordNetLemmatizer()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Customer sentimental/Amazon_review_main.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      reviewerID        asin      reviewerName helpful  \
# 0           0  A30TL5EWN6DFXT  120401325X         christina  [0, 0]
# 1           1   ASY55RVNIL0UD  120401325X          emily l.  [0, 0]
# 2           2  A2TMXE2AFO7ONB  120401325X             Erica  [0, 0]
# 3           3   AWJ0WZQYMYFQ4  120401325X                JM  [4, 4]
# 4           4   ATX7CZYFXI1KW  120401325X  patrice m rogoza  [2, 3]
#
#                                           reviewText  overall  \
# 0  They look good and stick good! I just don't li...        4
# 1  These stickers work like the review says they ...        5
# 2  These are awesome and make my phone look so st...        5
# 3  Item arrived in great time and was in perfect ...        4
# 4  awesome! stays on, and looks great. can be use...        5
#
#                                      summary  unixReviewTime   reviewTime
# 0                                 Looks Good      1400630400  05 21, 2014
# ...

# %%
# df= df.drop(['ID','Rating'], axis = 1)

# %%
fdf = df.copy()

# %%
sum = fdf['summary']

# %%
sum = pd.DataFrame(sum,columns = ['summary'])

# %%
sum
# Out:
#                                                   summary
# 0                                              Looks Good
# 1                                   Really great product.
# 2                                          LOVE LOVE LOVE
# 3                                                   Cute!
# 4               leopard home button sticker for iphone 4s
# ...                                                   ...
# 194434                           This works just perfect!
# 194435           Great replacement cable. Apple certified
# 194436                                       Real quality
# 194437  I really like it becasue it works well with my...
# 194438              I have wasted a lot of money on cords
#
# [194439 rows x 1 columns]

# %%
sum
# Out:
#                                                   summary
# 0                                              Looks Good
# 1                                   Really great product.
# 2                                          LOVE LOVE LOVE
# 3                                                   Cute!
# 4               leopard home button sticker for iphone 4s
# ...                                                   ...
# 194434                           This works just perfect!
# 194435           Great replacement cable. Apple certified
# 194436                                       Real quality
# 194437  I really like it becasue it works well with my...
# 194438              I have wasted a lot of money on cords
#
# [194439 rows x 1 columns]

# %%
sum.isnull().sum()
# Out:
# summary    0
# dtype: int64

# %%
sum.index[sum.isnull().any(axis=1)]
# Out:
# Int64Index([], dtype='int64')

# %%
sum
# Out:
#                                                   summary
# 0                                              Looks Good
# 1                                   Really great product.
# 2                                          LOVE LOVE LOVE
# 3                                                   Cute!
# 4               leopard home button sticker for iphone 4s
# ...                                                   ...
# 194434                           This works just perfect!
# 194435           Great replacement cable. Apple certified
# 194436                                       Real quality
# 194437  I really like it becasue it works well with my...
# 194438              I have wasted a lot of money on cords
#
# [194439 rows x 1 columns]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Download the 'stopwords' resource
nltk.download('stopwords')

# Download the 'wordnet' resource for lemmatization
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def DataPrep(text) :
    text = re.sub(r'\d+', '', text) # numbers
    text = re.sub(r'[^\w\s]', '', text) # special characters

    # tokenization
    tokens = nltk.word_tokenize(text)

    # remove puncs
    punc = list(punctuation)
    words = [word for word in tokens if word not in punc]

    # remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word.lower() for word in words if not word in stop_words]

    # lemmatization
    words = [lemma.lemmatize(word) for word in words]

    text = ' '.join(words)

    return text

# %%
sum['summary'] = sum['summary'].apply(DataPrep)

# %%
pip install flair
# Out:
# ...
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
# ...

# %%
pip install --upgrade urllib3
# Out:
# ...
#   Using cached urllib3-2.1.0-py3-none-any.whl (104 kB)
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.18
#     Uninstalling urllib3-1.26.18:
#       Successfully uninstalled urllib3-1.26.18
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# botocore 1.33.2 requires urllib3<2.1,>=1.25.4; python_version >= "3.10", but you have urllib3 2.1.0 which is incompatible.
# flair 0.13.0 requires urllib3<2.0.0,>=1.0.0, but you have urllib3 2.1.0 which is incompatible.
# ...

# %%
from flair.models import TextClassifier
from flair.data import Sentence
classifier = TextClassifier.load('sentiment')

def extract_sentiment_label(row):
    sentence = Sentence(row)
    classifier.predict(sentence)

    if sentence.labels:
        label = sentence.labels[0].value
        if label == 'POSITIVE':
            return "Positive"
        elif label == 'NEGATIVE':
            return "Negative"

    return "Neutral"
# Out:
# 2023-11-29 18:24:14,919 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_4.pt not found in cache, downloading to /tmp/tmpkk_rm26c
# 100%|██████████| 253M/253M [00:07<00:00, 36.9MB/s]
# 2023-11-29 18:24:22,333 copying /tmp/tmpkk_rm26c to cache at /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# 2023-11-29 18:24:23,027 removing temp file /tmp/tmpkk_rm26c
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
sum['label'] = df['summary'].apply(extract_sentiment_label)

# %%
sum
# Out:
#                                            summary     label
# 0                                        look good  Positive
# 1                             really great product  Positive
# 2                                   love love love  Positive
# 3                                             cute  Positive
# 4               leopard home button sticker iphone  Negative
# ...                                            ...       ...
# 194434                           this work perfect  Positive
# 194435     great replacement cable apple certified  Positive
# 194436                                real quality  Positive
# 194437  i really like becasue work well life proof  Positive
# 194438                     i wasted lot money cord  Negative
#
# [194439 rows x 2 columns]

# %%
xx = sum.label

# %%
xx = pd.DataFrame(xx,columns = ['label'])

# %%
df = pd.concat([df,xx],1)

# %%
df
# Out:
#         Unnamed: 0      reviewerID        asin       reviewerName helpful  \
# 0                0  A30TL5EWN6DFXT  120401325X          christina  [0, 0]
# 1                1   ASY55RVNIL0UD  120401325X           emily l.  [0, 0]
# 2                2  A2TMXE2AFO7ONB  120401325X              Erica  [0, 0]
# 3                3   AWJ0WZQYMYFQ4  120401325X                 JM  [4, 4]
# 4                4   ATX7CZYFXI1KW  120401325X   patrice m rogoza  [2, 3]
# ...            ...             ...         ...                ...     ...
# 194434      194434  A1YMNTFLNDYQ1F  B00LORXVUE    eyeused2loveher  [0, 0]
# 194435      194435  A15TX8B2L8B20S  B00LORXVUE       Jon Davidson  [0, 0]
# 194436      194436  A3JI7QRZO1QG8X  B00LORXVUE  Joyce M. Davidson  [0, 0]
# 194437      194437  A1NHB2VC68YQNM  B00LORXVUE     Nurse Farrugia  [0, 0]
# 194438      194438  A1AG6U022WHXBF  B00LORXVUE     Trisha Crocker  [0, 0]
#
#                                                reviewText  overall  \
# ...

# %%
df.to_csv('Amazon Final Data with Label.csv')
